# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns #必要なライブラリをインポート（使えるようにする）

# %%
from sklearn.linear_model import LinearRegression #sklearnの線形回帰モデルをインポート

# %%
from sklearn.model_selection import train_test_split #データを学習用とテスト用に分割するための関数をインポート

# %%
df = pd.read_excel("test_result2.xlsx") #実験結果を読み込んで、dfという変数に格納

# %%
df #dfに格納されたデータを表示
# Out:
#     半金比率(%)  ドーピング濃度[mg/ml]       減少率
# 0       100           0.004  0.192643
# 1       100           0.016  0.082326
# 2       100           0.032  0.042399
# 3        95           0.004  0.259153
# 4        95           0.016  0.100682
# 5        95           0.032  0.068291
# 6        90           0.004  0.364334
# 7        90           0.016  0.205307
# 8        90           0.032  0.106803
# 9       100           0.004  0.125703
# 10      100           0.016  0.026107
# 11      100           0.032  0.015551
# 12       95           0.004  0.371106
# 13       95           0.016  0.167836
# 14       95           0.032  0.115336
# 15       90           0.004  0.568194
# 16       90           0.016  0.184675
# 17       90           0.032  0.134816
# 18      100           0.004  0.122440
# 19      100           0.016  0.029748
# 20      100           0.032  0.010415
# 21       95           0.004  0.129270
# 22       95           0.016  0.041491
# 23       95           0.032  0.020342
# ...

# %%
df.columns = ['halfgold_ratio', 'doping_concentration', 'resistance_reduction'] #列名が日本語になっているので、英語に変更

# %%
df #変更されているか確認
# Out:
#     halfgold_ratio  doping_concentration  resistance_reduction
# 0              100                 0.004              0.192643
# 1              100                 0.016              0.082326
# 2              100                 0.032              0.042399
# 3               95                 0.004              0.259153
# 4               95                 0.016              0.100682
# 5               95                 0.032              0.068291
# 6               90                 0.004              0.364334
# 7               90                 0.016              0.205307
# 8               90                 0.032              0.106803
# 9              100                 0.004              0.125703
# 10             100                 0.016              0.026107
# 11             100                 0.032              0.015551
# 12              95                 0.004              0.371106
# 13              95                 0.016              0.167836
# ...

# %%
x = df[['halfgold_ratio', 'doping_concentration']]
y = df['resistance_reduction'] #目的関数をyに入れる

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1) #学習用とテスト用にデータを分割（例: 80%学習, 20%テスト）

# %%
len(x_train), len(x_test) #学習用とテスト用のデータ数を確認
# Out:
# (28, 8)

# %%
model = LinearRegression() #線形回帰モデルを作成
model.fit(x_train, y_train) #モデルに自分のデータを学習させる
# Out:
# LinearRegression()

# %%
print(f'train scoer: {model.score(x_train, y_train)}') #学習用スコアと予測したモデルの比較
print(f'test scoer: {model.score(x_test, y_test)}') #テスト用スコアと予測したモデルの比較　♯1がMAXだけど0.37は低すぎるね。データが少ないから？
# Out:
# train scoer: 0.6473939270059443
# test scoer: 0.5063506477512592

# %%
t= model.predict(x_test) #テスト用データの予測値を表示

# %%
print(f'予測値: {t[1]}')              # テスト用データの予測値を表示 #抵抗値がマイナスの域に行く！すごい！
print(f'実測値: {y_test.iloc[1]}')    # テスト用データの実測値を表示
# Out:
# 予測値: 0.225191972957681
# 実測値: 0.137660505

# %%
# テスト用データの予測値と実測値を一覧で表示
for i in range(len(t)):
    print(f'予測値: {t[i]:.3f} / 実測値: {y_test.iloc[i]:.3f}')
# Out:
# 予測値: 0.238 / 実測値: 0.214
# 予測値: 0.225 / 実測値: 0.138
# 予測値: 0.084 / 実測値: 0.045
# 予測値: 0.238 / 実測値: 0.259
# 予測値: 0.084 / 実測値: 0.030
# 予測値: 0.114 / 実測値: 0.135
# 予測値: 0.238 / 実測値: 0.129
# 予測値: 0.044 / 実測値: 0.020

# %%
import itertools
# 予測したい値の組み合わせを作成
halfgold_range = range(100, 89, -1)  # 100,99,...,90

all_results = []  # 結果を蓄積するリスト

for x in np.arange(0.001, 0.032 + 0.001, 0.001):
    doping_range = [round(x, 3)]  # 1ステップ分だけ

    predict_df = pd.DataFrame(
        list(itertools.product(halfgold_range, doping_range)),
        columns=['halfgold_ratio', 'doping_concentration']
    )

    # 予測
    predicted = model.predict(predict_df)

    # DataFrameに予測結果を追加
    predict_df['predicted'] = predicted

    # 蓄積
    all_results.append(predict_df)

# 全体を結合して1つのDataFrameに
final_df = pd.concat(all_results, ignore_index=True)

# CSVに保存
final_df.to_csv("prediction_results.csv", index=False)

print("CSVファイル 'prediction_results.csv' を保存しました。")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[27], line 28
#      25 final_df = pd.concat(all_results, ignore_index=True)
#      27 # CSVに保存
# ---> 28 final_df.to_csv("prediction_results.csv", index=False)
#      30 print("CSVファイル 'prediction_results.csv' を保存しました。")
#
# File c:\Users\sumik\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
